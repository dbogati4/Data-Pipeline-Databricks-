# %% [markdown]
# Load the CSV file

# %%
# %fs ls /databricks-datasets/COVID/USAFacts/covid_confirmed_usafacts.csv

# %%
covid_df = spark.read.csv("/databricks-datasets/COVID/USAFacts/covid_confirmed_usafacts.csv", header=True, inferSchema=True)
